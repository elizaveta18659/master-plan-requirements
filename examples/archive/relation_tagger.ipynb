# %%
import os
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
from tqdm import tqdm

# %% [markdown]
# Определяем теги у точек

# %%
#загрузка слоев
def load_layers(folder_path, service_tags):
    service_layers = {}
    for tag in service_tags:
        file_path = os.path.join(folder_path, f"{tag}.geojson")  # Формируем путь к файлу
        if os.path.exists(file_path):  # Проверяем, существует ли файл
            try:
                # Загружаем слой в GeoDataFrame
                gdf = gpd.read_file(file_path)

                # Добавляем столбец с названием тега
                gdf['SERVICE'] = tag

                # Сохраняем только геометрию и название сервиса
                gdf = gdf[["geometry", "SERVICE"]]

                # Сохраняем слой в словарь
                service_layers[tag] = gdf
                print(f"Загружен и обновлен слой: {tag}")
            except Exception as e:
                print(f"Ошибка при загрузке или обработке слоя {tag}: {e}")
        else:
            print(f"Файл для тега '{tag}' не найден.")
    return service_layers

# %%
# Папка, где находятся слои
folder_path = "./data/serv"

# %%
MED_layers = load_layers(folder_path, MEDICAL_FACILITIES_tags)
# Out:
# Загружен и обновлен слой: child_hospital
# Загружен и обновлен слой: child_polyclinic
# Загружен и обновлен слой: dentist

# %%
MED_layers
# Out:
# {'child_hospital':                      geometry         SERVICE
#  0   POINT (30.26735 59.94232)  child_hospital
#  1   POINT (30.33768 60.00438)  child_hospital
#  2   POINT (30.28141 59.94687)  child_hospital
#  3   POINT (30.37815 59.71048)  child_hospital
#  4   POINT (30.18588 59.83767)  child_hospital
#  5   POINT (30.26079 59.93432)  child_hospital
#  6   POINT (30.41807 59.83872)  child_hospital
#  7   POINT (30.32563 60.01711)  child_hospital
#  8   POINT (30.33061 59.98933)  child_hospital
#  9   POINT (30.59565 59.74856)  child_hospital
#  10  POINT (30.36433 59.93441)  child_hospital
#  11  POINT (30.36767 59.93241)  child_hospital
#  12  POINT (30.34314 59.98067)  child_hospital
#  13  POINT (30.29147 59.92516)  child_hospital
#  14  POINT (30.36757 59.95403)  child_hospital
#  15  POINT (30.36757 59.95403)  child_hospital
#  16  POINT (30.31760 59.97185)  child_hospital
#  17  POINT (30.32595 59.96602)  child_hospital
#  18  POINT (30.41618 59.88245)  child_hospital
#  19  POINT (30.31165 59.97371)  child_hospital,
#  'child_polyclinic':                      geometry           SERVICE
#  0   POINT (30.27564 59.94478)  child_polyclinic
#  1   POINT (30.41375 59.98290)  child_polyclinic
#  2   POINT (30.20119 59.85914)  child_polyclinic
#  3   POINT (30.37463 59.86176)  child_polyclinic
#  4   POINT (30.36772 59.87337)  child_polyclinic
#  ..                        ...               ...
#  80  POINT (30.24523 59.84119)  child_polyclinic
#  81  POINT (30.36400 59.94608)  child_polyclinic
#  82  POINT (30.24463 60.02559)  child_polyclinic
#  83  POINT (30.21280 59.99125)  child_polyclinic
#  84  POINT (30.28541 59.98756)  child_polyclinic
#
#  [85 rows x 2 columns],
#  'dentist':                       geometry  SERVICE
#  0    POINT (30.32683 59.85368)  dentist
#  1    POINT (30.32662 59.85072)  dentist
#  2    POINT (30.27986 59.85235)  dentist
#  3    POINT (30.42797 59.72429)  dentist
#  4    POINT (30.34108 59.98423)  dentist
#  ..                         ...      ...
#  958  POINT (30.26403 59.93487)  dentist
#  959  POINT (30.32023 59.88977)  dentist
#  960  POINT (30.27156 59.88744)  dentist
#  961  POINT (30.26551 59.87071)  dentist
#  962  POINT (30.30965 59.92520)  dentist
#
#  [963 rows x 2 columns]}

# %%
def merge_layers(service_layers):
    # Создаем список слоев, которые будем преобразовывать в нужную систему координат
    transformed_layers = []

    for layer in service_layers.values():
        # Проверка, имеет ли слой CRS
        if layer.crs is None:
            raise ValueError("Система координат не установлена в одном из слоев.")

        # Если CRS не в EPSG:3857, выполняем преобразование
        if layer.crs.to_epsg() != 3857:
            layer = layer.to_crs(epsg=3857)
            print(f"Система координат слоя была переведена в EPSG:3857.")

        # Добавляем преобразованный слой в список
        transformed_layers.append(layer)

    # Объединяем все слои в один DataFrame
    all_layers = pd.concat(transformed_layers, ignore_index=True)
    
    # Оставляем только столбцы 'geometry' и 'SERVICE'
    all_layers = all_layers[['geometry', 'SERVICE']]
    
    # Преобразуем в GeoDataFrame с корректной геометрией
    all_layers = gpd.GeoDataFrame(all_layers, geometry='geometry')

    return all_layers

# %%
MED_gdf = merge_layers(MED_layers)
# Out:
# Система координат слоя была переведена в EPSG:3857.
# Система координат слоя была переведена в EPSG:3857.
# Система координат слоя была переведена в EPSG:3857.

# %%
MED_gdf = MED_gdf.to_crs(epsg=3857)

# %%
MED_gdf.head(1)
# Out:
#                           geometry         SERVICE
# 0  POINT (3369346.324 8386906.143)  child_hospital

# %%
MED_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8afc86664e4eb37a0981affd3f5d78ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8afc86664e4eb37a0981affd3f5d78ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8afc86664e4eb37a0981affd3f5d78ee = L.map(
#                 &quot;map_8afc86664e4eb37a0981affd3f5d78ee&quot;,
#                 {
#                     center: [59.94151245562961, 30.163408237851613],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8afc86664e4eb37a0981affd3f5d78ee);
#
#
#
#
#
#             var tile_layer_2e22bead3150bb177cce91dec2b2a37a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8afc86664e4eb37a0981affd3f5d78ee);
#
#
#             map_8afc86664e4eb37a0981affd3f5d78ee.fitBounds(
#                 [[59.683899911259246, 29.708277999999993], [60.19912499999998, 30.618538475703236]],
#                 {}
#             );
#
#
#         function geo_json_ac161f7c93369d6b437925c90fc77d31_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ac161f7c93369d6b437925c90fc77d31_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ac161f7c93369d6b437925c90fc77d31_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_ac161f7c93369d6b437925c90fc77d31_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ac161f7c93369d6b437925c90fc77d31_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_ac161f7c93369d6b437925c90fc77d31.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_ac161f7c93369d6b437925c90fc77d31_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_ac161f7c93369d6b437925c90fc77d31 = L.geoJson(null, {
#                 onEachFeature: geo_json_ac161f7c93369d6b437925c90fc77d31_onEachFeature,
#
#                 style: geo_json_ac161f7c93369d6b437925c90fc77d31_styler,
#                 pointToLayer: geo_json_ac161f7c93369d6b437925c90fc77d31_pointToLayer
#         });
#
#         function geo_json_ac161f7c93369d6b437925c90fc77d31_add (data) {
#             geo_json_ac161f7c93369d6b437925c90fc77d31
#                 .addData(data)
#                 .addTo(map_8afc86664e4eb37a0981affd3f5d78ee);
#         }
#             geo_json_ac161f7c93369d6b437925c90fc77d31_add({&quot;bbox&quot;: [29.708277999999993, 59.683899911259246, 30.618538475703236, 60.19912499999998], &quot;features&quot;: [{&quot;bbox&quot;: [30.267352999999993, 59.94231500000001, 30.267352999999993, 59.94231500000001], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.267352999999993, 59.94231500000001], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;SERVICE&quot;: &quot;child_hospital&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [30.337676999999996, 60.00437599999999, 30.337676999999996, 60.00437599999999], &quot;geometry&quot;: {&quot;coordinates&quot

# %% [markdown]
# Создаем буфер у каждого сервиса

# %%
def build_buffer_zone(gdf, service_radius_dict):
    gdf['buffer'] = gdf.apply(
    lambda row: row['geometry'].buffer(service_radius_dict.get(row['SERVICE'])), axis=1)
    return gdf

# %%
MED_buffer = build_buffer_zone(MED_gdf, MEDICAL_FACILITIES_tags)

# %%
print(MED_buffer.crs)
# Out:
# EPSG:3857

# %%
MED_buffer.head()
# Out:
#                           geometry         SERVICE  \
# 0  POINT (3369346.324 8386906.143)  child_hospital
# 1  POINT (3377174.755 8400712.222)  child_hospital
# 2  POINT (3370911.698 8387919.457)  child_hospital
# 3  POINT (3381680.542 8335560.029)  child_hospital
# 4  POINT (3360276.457 8363686.129)  child_hospital
#
#                                               buffer
# 0  POLYGON ((3369846.324 8386906.143, 3369843.916...
# 1  POLYGON ((3377674.755 8400712.222, 3377672.348...
# 2  POLYGON ((3371411.698 8387919.457, 3371409.291...
# 3  POLYGON ((3382180.542 8335560.029, 3382178.135...
# 4  POLYGON ((3360776.457 8363686.129, 3360774.049...

# %% [markdown]
# Пересечение сервисов и кварталов

# %%
#загружаем геометрию кварталов
blocks_gdf = gpd.read_file("./data/blocks_relation_tagger.geojson")

# %%
blocks_gdf = blocks_gdf.to_crs(epsg=3857)

# %%
def create_service_table(blocks_gdf, service_tags):
    # Добавляем столбцы для каждого сервиса с начальными значениями 0
    for service in service_tags.keys():
        blocks_gdf[service] = 0

    # Добавляем столбцы для каждого сервиса с начальными значениями 0
    for service in service_tags.keys():
        blocks_gdf['SERVICE'] = 0

    return blocks_gdf

# %%
MED_blocks_gdf = create_service_table(blocks_gdf, MEDICAL_FACILITIES_tags)
MED_blocks_gdf.head(1)
# Out:
#    id                                           geometry  child_hospital  \
# 0   0  POLYGON ((3385731.840 8387954.044, 3385731.840...               0
#
#    child_polyclinic  dentist  SERVICE
# 0                 0        0        0

# %%
print(MED_blocks_gdf.crs)
# Out:
# EPSG:3857

# %%
def check_intersection(blocks_gdf, buffer_gdf, service_tags):
    for idx, block in tqdm(blocks_gdf.iterrows(), total=blocks_gdf.shape[0], desc="Processing blocks"):
        for service in service_tags.keys():
            # Получаем буферы для текущего сервиса
            relevant_buffers = buffer_gdf.loc[buffer_gdf['SERVICE'] == service, 'geometry']
            
            if not relevant_buffers.empty:
                for buffer_geom in relevant_buffers:
                    intersection = block['geometry'].intersection(buffer_geom)
                    # Проверяем, пересекается ли хотя бы 10% буфера
                    if intersection.area >= 0.1 * buffer_geom.area:
                        blocks_gdf.at[idx, service] = 1
    
    # Устанавливаем столбец 'SERVICE' для блоков, которые пересекаются с хотя бы одним сервисом
    blocks_gdf['SERVICE'] = blocks_gdf.apply(
        lambda row: 1 if any(row[service] == 1 for service in service_tags.keys()) else 0,
        axis=1
    )
    
    return blocks_gdf

# %%
MED_blocks_service_gdf = check_intersection(MED_blocks_gdf, MED_buffer, MEDICAL_FACILITIES_tags)
# Out:
# Processing blocks: 100%|██████████| 3839/3839 [02:40<00:00, 23.86it/s]

# %%
MED_blocks_service_gdf.head(1)
# Out:
#    id                                           geometry  child_hospital  \
# 0   0  POLYGON ((3385731.840 8387954.044, 3385731.840...               1
#
#    child_polyclinic  dentist  SERVICE
# 0                 1        1        1
